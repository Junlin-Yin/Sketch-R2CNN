# %%
from google.colab import drive
drive.mount('/content/drive')
# !lsb_release -a
# !nvidia-smi
# !/opt/conda/bin/python --version

# %%
# !apt-get update && apt-get install -y --no-install-recommends build-essential ca-certificates software-properties-common
# !add-apt-repository ppa:jeff250/opencv
# !apt-get update && apt-get install -y --no-install-recommends cmake curl git libgtk2.0-0 libopencv2.4-java libjpeg-dev liblmdb-dev \
  libopenblas-dev libopencv-contrib-dev libopencv-dev libopencv-nonfree-dev libmpich-dev libpng-dev libsm6 libxext6 ninja-build \
  openmpi-bin openmpi-doc pkg-config rsync unzip vim wget zlib1g zlib1g-dev imagemagick && rm -rf /var/lib/apt/lists/*
# !wget https://support.hdfgroup.org/ftp/HDF5/releases/hdf5-1.10/hdf5-1.10.5/src/hdf5-1.10.5.tar.gz -O ~/hdf5.tar.gz && \
  tar -xvzf ~/hdf5.tar.gz -C ~/ && cd ~/hdf5-1.10.5 && \
  ./configure --enable-parallel --enable-shared --prefix=/usr/local/hdf5 && \
  make -j 4 && make install -j 4 && cd ~ && rm -rf ~/hdf5-1.10.5 && rm ~/hdf5.tar.gz
# !wget https://repo.continuum.io/miniconda/Miniconda3-4.3.14-Linux-x86_64.sh -O ~/miniconda.sh && \
  /bin/bash ~/miniconda.sh -b -p /opt/conda && rm ~/miniconda.sh
# !/opt/conda/bin/conda install -c anaconda protobuf
# !/opt/conda/bin/pip install --upgrade pip
# !/opt/conda/bin/pip install --upgrade --ignore-installed setuptools
# !/opt/conda/bin/pip install numpy scipy scikit-image matplotlib pytz PyYAML Pillow tqdm protobuf ninja lmdb addict fire rdp opencv-python typing mpi4py
# !/opt/conda/bin/pip install torch torchvision pytorch-ignite tensorboardX
# !/opt/conda/bin/pip install git+https://github.com/rbgirshick/yacs
# !/opt/conda/bin/pip install git+https://github.com/Cadene/pretrained-models.pytorch
# !export CC=mpicc && export HDF5_MPI="ON" && export HDF5_DIR=/usr/local/hdf5 && /opt/conda/bin/pip install --no-binary=h5py h5py
# !/opt/conda/bin/conda clean -y --all
# !export LANG=C.UTF-8
# !export LC_ALL=C.UTF-8
# !export LD_LIBRARY_PATH=.:/usr/local/hdf5/lib:/usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/lib64:$LD_LIBRARY_PATH
# !export PATH=/usr/local/hdf5/bin:/usr/local/cuda/bin:/opt/conda/bin:$PATH
# !export CPATH=/usr/local/cuda/include:$CPATH

# %%
# !sh "/content/drive/My Drive/Sketch-R2CNN/scripts/tuberlin_r2cnn_train.sh"

# %%
# !sh "/content/drive/My Drive/Sketch-R2CNN/scripts/tuberlin_r2cnn_eval.sh"
